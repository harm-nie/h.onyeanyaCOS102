# %%
import pandas as pd
girls_data = {
'names': ['evelyn' , 'jessica' , 'somto' , 'edith' , 'liza' , 'madonna' , 'waje' , 'tola' , 'aisha', 'latifa'], 
'age': [17 , 16 , 17 , 18 , 16 , 18 , 17 , 20 , 19 , 17],
 'height': [5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5],
 'scores': [80,85,70,60,76,66,87,95,50,49],
}
gd = pd.DataFrame(girls_data)
print(gd)

# representation of boys data
boys_data = {
 'names': ['chinedu','liam','wale','gbenga','abiola','kola','kunle','george','thomas','wesley'],
  'age': [19,16,18,17,20,19,16,18,17,19],
    'height': [5.7,5.9,5.8,6.1,5.9,5.5,6.1,5.4,5.8,5.7],
    'scores': [74,87,75,68,66,78,87,98,54,60],
}
bd = pd.DataFrame(boys_data)
print(bd)
# Out:
#      names  age  height  scores
# 0   evelyn   17     5.5      80
# 1  jessica   16     6.0      85
# 2    somto   17     5.4      70
# 3    edith   18     5.9      60
# 4     liza   16     5.6      76
# 5  madonna   18     5.5      66
# 6     waje   17     6.1      87
# 7     tola   20     6.0      95
# 8    aisha   19     5.7      50
# 9   latifa   17     5.5      49
#      names  age  height  scores
# 0  chinedu   19     5.7      74
# 1     liam   16     5.9      87
# 2     wale   18     5.8      75
# 3   gbenga   17     6.1      68
# 4   abiola   20     5.9      66
# 5     kola   19     5.5      78
# 6    kunle   16     6.1      87
# 7   george   18     5.4      98
# 8   thomas   17     5.8      54
# 9   wesley   19     5.7      60

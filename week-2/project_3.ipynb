# %%
#input
names = [
    "Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa",
    "Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"
]

age = [ 17, 16, 17, 18, 16, 18, 17, 20, 19, 17, 19, 16, 18, 17, 20, 19, 16, 18, 17, 19]

height = [ 5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5, 5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]

scores = [ 80, 85, 70, 60, 76, 66, 87, 95, 50, 49, 74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

print("------------ STUDENT DATA TABLE -----------")
print("-"*39)

print(f"{'NAME':^12} | {'AGE':^5} | {'HEIGHT':^7} | {'SCORES':^5}")
print("-"*39)

for i in range(len(names)):
    
    print(f"{names[i]:<12} | {age[i]:<5} | {height[i]:<7} | {scores[i]:<5}")
    print("-"*39)
# Out:
# ------------ STUDENT DATA TABLE -----------
# ---------------------------------------
#     NAME     |  AGE  | HEIGHT  | SCORES
# ---------------------------------------
# Evelyn       | 17    | 5.5     | 80
# ---------------------------------------
# Jessica      | 16    | 6.0     | 85
# ---------------------------------------
# Somto        | 17    | 5.4     | 70
# ---------------------------------------
# Edith        | 18    | 5.9     | 60
# ---------------------------------------
# Liza         | 16    | 5.6     | 76
# ---------------------------------------
# Madonna      | 18    | 5.5     | 66
# ---------------------------------------
# Waje         | 17    | 6.1     | 87
# ---------------------------------------
# Tola         | 20    | 6.0     | 95
# ---------------------------------------
# Aisha        | 19    | 5.7     | 50
# ---------------------------------------
# Latifa       | 17    | 5.5     | 49
# ---------------------------------------
# ...

# %% [markdown]
# Pseudocode: Student Data Table Generator
# BEGIN
#
# INITIALIZE four lists containing the data:
#
# Names (List of 20 strings)
#
# Ages (List of 20 integers)
#
# Heights (List of 20 decimals)
#
# Scores (List of 20 integers)
#
# DISPLAY the table header:
#
# Print "NAME", "AGE", "HEIGHT", and "SCORES" with center alignment.
#
# Print a horizontal line of dashes for visual separation.
#
# START LOOP from index 0 to the end of the lists (length - 1):
#
# GET the current Name, Age, Height, and Score using the current index.
#
# FORMAT the data into a single string with specific column widths (padding).
#
# DISPLAY the formatted row.
#
# DISPLAY a horizontal line of dashes.
# END LOOP
#
# END
